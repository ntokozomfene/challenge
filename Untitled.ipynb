# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
test = pd.read_csv('akeelah_testt.csv')
train_1 = pd.read_csv('akeelah_train1.csv')

# %%
train = train_1[(train_1.index>np.percentile(train_1.index, 33)) & (train_1.index<=np.percentile(train_1.index, 66))]

# %%
train.head()
# Out:
#        customer_id         created_at_x         updated_at_x  location_number  \
# 478698     IYCLJ92  2018-09-27 22:20:57  2018-09-27 22:20:57                0
# 478699     IYCLJ92  2018-09-27 22:20:57  2018-09-27 22:20:57                0
# 478700     ED0DUST  2018-09-27 22:27:01  2018-09-27 22:27:00                0
# 478701     ED0DUST  2018-09-27 22:27:01  2018-09-27 22:27:00                0
# 478702     ED0DUST  2018-09-27 22:27:01  2018-09-27 22:27:00                0
#
#        location_type  latitude_x  longitude_x   id  authentication_id  \
# 478698          Home      0.6533        -78.7  858           130468.0
# 478699          Home      0.6533        -78.7  907           132953.0
# 478700           NaN      0.6520        -78.7    4           118597.0
# 478701           NaN      0.6520        -78.7   13           118608.0
# 478702           NaN      0.6520        -78.7   20           118616.0
#
#         latitude_y  ...  country_id city_id         created_at_y  \
# ...

# %%
train.describe()
# Out:
#        location_number     latitude_x    longitude_x             id  \
# count    478698.000000  478598.000000  478598.000000  478698.000000
# mean          1.065181      -0.026184     -34.759576     288.837632
# std           1.422587      13.659907      39.217317     241.083423
# min           0.000000    -669.500000    -132.200000       4.000000
# 25%           0.000000      -0.421400     -78.560000     105.250000
# 50%           1.000000      -0.091250      -0.012050     201.000000
# 75%           2.000000       0.160800       0.427200     386.000000
# max          11.000000     453.800000      43.560000     907.000000
#
#        authentication_id     latitude_y    longitude_y  vendor_category_id  \
# count      478698.000000  478698.000000  478698.000000       478698.000000
# mean       120050.716496       1.875093       0.803797            2.110000
# std          3491.425703      20.493464       4.376737            0.312891
# ...

# %%
for col in train.columns:
    print(train[col].isnull().value_counts())
# Out:
# False    478698
# Name: customer_id, dtype: int64
# False    478698
# Name: created_at_x, dtype: int64
# False    478698
# Name: updated_at_x, dtype: int64
# False    478698
# Name: location_number, dtype: int64
# True     240696
# False    238002
# Name: location_type, dtype: int64
# False    478598
# True        100
# Name: latitude_x, dtype: int64
# False    478598
# True        100
# Name: longitude_x, dtype: int64
# False    478698
# Name: id, dtype: int64
# False    478698
# Name: authentication_id, dtype: int64
# False    478698
# Name: latitude_y, dtype: int64
# False    478698
# Name: longitude_y, dtype: int64
# False    478698
# Name: vendor_category_en, dtype: int64
# False    478698
# Name: vendor_category_id, dtype: int64
# False    478698
# Name: delivery_charge, dtype: int64
# False    478698
# Name: serving_distance, dtype: int64
# False    478698
# Name: is_open, dtype: int64
# False    435617
# True      43081
# Name: OpeningTime, dtype: int64
# False    435617
# ...

# %%
# drop columns with 20 % or more null value
train.drop(['location_number','customer_id','rank','commission','OpeningTime2','OpeningTime','location_type','sunday_from_time1', 'sunday_to_time1',
       'sunday_from_time2', 'sunday_to_time2', 'monday_from_time1',
       'monday_to_time1', 'monday_from_time2', 'monday_to_time2',
       'tuesday_from_time1', 'tuesday_to_time1', 'tuesday_from_time2',
       'tuesday_to_time2', 'wednesday_from_time1', 'wednesday_to_time1',
       'wednesday_from_time2', 'wednesday_to_time2', 'thursday_from_time1',
       'thursday_to_time1', 'thursday_from_time2', 'thursday_to_time2',
       'friday_from_time1', 'friday_to_time1', 'friday_from_time2',
       'friday_to_time2', 'saturday_from_time1', 'saturday_to_time1',
       'saturday_from_time2', 'saturday_to_time2', 'primary_tags'], axis=1 ,inplace=True)
# Out:
# C:\Users\Mr.mfene\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
# Impute the missing values with mode imputation
train.fillna(train.mode(), inplace=True)
# Out:
# C:\Users\Mr.mfene\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:4034: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)

# %%
train.shape
# Out:
# (478698, 25)

# %%
fig, ax = plt.subplots(figsize=(20,20)) 
sns.heatmap(train.corr(), annot=True)
plt.show()

# %%
train.isnull().count()
# Out:
# created_at_x              478698
# updated_at_x              478698
# latitude_x                478698
# longitude_x               478698
# id                        478698
# authentication_id         478698
# latitude_y                478698
# longitude_y               478698
# vendor_category_en        478698
# vendor_category_id        478698
# delivery_charge           478698
# serving_distance          478698
# is_open                   478698
# prepration_time           478698
# is_akeed_delivering       478698
# discount_percentage       478698
# status                    478698
# verified                  478698
# language                  478698
# vendor_rating             478698
# open_close_flags          478698
# vendor_tag                478698
# vendor_tag_name           478698
# one_click_vendor          478698
# country_id                478698
# city_id                   478698
# created_at_y              478698
# updated_at_y              478698
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 478698 entries, 478698 to 957395
# Data columns (total 34 columns):
# created_at_x              478698 non-null object
# updated_at_x              478698 non-null object
# latitude_x                478598 non-null float64
# longitude_x               478598 non-null float64
# id                        478698 non-null int64
# authentication_id         478698 non-null float64
# latitude_y                478698 non-null float64
# longitude_y               478698 non-null float64
# vendor_category_en        478698 non-null object
# vendor_category_id        478698 non-null float64
# delivery_charge           478698 non-null float64
# serving_distance          478698 non-null float64
# is_open                   478698 non-null float64
# prepration_time           478698 non-null int64
# is_akeed_delivering       478698 non-null object
# discount_percentage       478698 non-null float64
# status                    478698 non-null float64
# ...

# %%
X=train[['open_close_flags',
       'vendor_tag', 'vendor_tag_name', 'one_click_vendor', 'country_id',
       'city_id', 'created_at_y', 'updated_at_y',
       'display_orders']]
for col in X.columns:
    print(X[col].value_counts())
# Out:
# 1.0    478698
# Name: open_close_flags, dtype: int64
# 1,4,5,6,8,91,30,43,48,24     33508
# 1,5,91,29,27                 14361
# 38,16,23                     14361
# 60,38,61,16,36               14361
# 31,8,10,44,33                14361
# 4,8,22,32,24,16,28           14361
# 1,5,48,27,16,36,28,35         9574
# 38,32,52,16,23                9574
# 1,5,30,16                     9574
# 5,8,91,27,16                  9574
# 2,71,16                       4787
# 1,5,47,24,16                  4787
# 4,41,51,34,27,15,24,16,28     4787
# 5,30,48,23                    4787
# 1,5,30,52                     4787
# 91,42,24                      4787
# 3,58,22,11,33,28              4787
# 5,30,22,47,52,16,56           4787
# 1,5,48,16                     4787
# 2,4,5,8,91,22,12,24,16,23     4787
# 31,8,10,28                    4787
# 1,5,16                        4787
# 8,91,38,9,43,32,52            4787
# 2,31,7,22,10,33,24,28,19      4787
# 64,36                         4787
# ...

# %%
train.drop(['open_close_flags',
       'vendor_tag', 'vendor_tag_name', 'one_click_vendor', 'country_id',
       'city_id', 'created_at_y', 'updated_at_y',
       'display_orders'],axis=1, inplace=True)

# %%
import matplotlib.pyplot as plt 
# sns.pairplot(train)
# plt.show()

# %%
# X=train.iloc[:,:24]
# y=train.iloc[:,24]

# %%
train.columns
# Out:
# Index(['created_at_x', 'updated_at_x', 'latitude_x', 'longitude_x', 'id',
#        'authentication_id', 'latitude_y', 'longitude_y', 'vendor_category_en',
#        'vendor_category_id', 'delivery_charge', 'serving_distance', 'is_open',
#        'prepration_time', 'is_akeed_delivering', 'discount_percentage',
#        'status', 'verified', 'language', 'vendor_rating', 'device_type',
#        'location_number_obj', 'id_obj', 'CID X LOC_NUM X VENDOR', 'target'],
#       dtype='object')

# %%
sns.countplot(x='target', hue='CID X LOC_NUM X VENDOR', data=train)
plt.title("count the classes")
plt.show()
